# %% [markdown]
# #### Rhythm's .MAT and .CSV Data Separator

# %%
import scipy.io
import numpy as np
import pandas as pd
import os
import shutil

# File paths
ecg_rhythm_file = '../02_Diagnosis_PreProcess/DiagnosticInfo_rhythm.csv'
source_folder = '../01_Database_PhysioNet'
target_folder = '../01_Database_ECGSignal_Rhythm'

# Read the IDs from ECGSignal_ID_rhythm.csv
df_rhythm = pd.read_csv(ecg_rhythm_file)
rhythm_ids = df_rhythm['ID'].values

# Clean the target folder if it exists, otherwise create it
if not os.path.exists(target_folder):
    os.makedirs(target_folder)

# Check the .mat and .hea files in the 01_Database_PhysioNet folder and copy the relevant ones
for filename in os.listdir(source_folder):
    # Extract file ID from filename
    file_id = filename.split('.')[0]  # e.g., J00001.mat -> J00001
    
    if filename.endswith('.mat') or filename.endswith('.hea'):  # Check .mat and .hea files
        if file_id in rhythm_ids:  # If the file ID is in the list
            source_path = os.path.join(source_folder, filename)
            target_path = os.path.join(target_folder, filename)
            shutil.copy(source_path, target_path)  # Copy the file

print("Process completed.")
# Out:
# Process completed.

# %% [markdown]
# #### MAT to CSV Converter

# %%
import scipy.io
import numpy as np
import pandas as pd
import os

# Folder path
mat_folder = '../01_Database_ECGSignal_Rhythm'

# Header information
headers = ["I", "II", "III", "aVR", "aVL", "aVF", "V1", "V2", "V3", "V4", "V5", "V6"]

# Function to convert .mat files to .csv
def mat_to_csv(mat_folder):
    # Get all .mat files in the folder
    for file_name in os.listdir(mat_folder):
        if file_name.endswith(".mat"):
            mat_file_path = os.path.join(mat_folder, file_name)
            
            # Load the .mat file
            mat_data = scipy.io.loadmat(mat_file_path)
            
            # Get the ECG data (12x5000 format)
            ecg_data = mat_data.get('val')  # The variable name 'val' may vary depending on the .mat file
            
            if ecg_data is not None:
                ecg_data = ecg_data.T  # Transpose to get the 5000x12 format
                
                # Save as a CSV file
                output_csv = os.path.join(mat_folder, file_name.replace(".mat", ".csv"))
                df = pd.DataFrame(ecg_data, columns=headers)
                df.to_csv(output_csv, index=False)
                print(f"Converted {file_name} to CSV.")
            else:
                print(f"ECGSignal not found in {file_name}.")
                
# Call the function
mat_to_csv(mat_folder)
# Out:
# Converted JS33748.mat to CSV.
# Converted JS13498.mat to CSV.
# Converted JS34027.mat to CSV.
# Converted JS22645.mat to CSV.
# Converted JS33990.mat to CSV.
# Converted JS35339.mat to CSV.
# Converted JS02595.mat to CSV.
# Converted JS32456.mat to CSV.
# Converted JS03853.mat to CSV.
# Converted JS12786.mat to CSV.
# Converted JS26423.mat to CSV.
# Converted JS29710.mat to CSV.
# Converted JS17826.mat to CSV.
# Converted JS08906.mat to CSV.
# Converted JS36630.mat to CSV.
# Converted JS39503.mat to CSV.
# Converted JS00382.mat to CSV.
# Converted JS20052.mat to CSV.
# Converted JS10191.mat to CSV.
# Converted JS30241.mat to CSV.
# Converted JS01922.mat to CSV.
# Converted JS28368.mat to CSV.
# Converted JS30527.mat to CSV.
# Converted JS37248.mat to CSV.
# Converted JS20734.mat to CSV.
# Converted JS17198.mat to CSV.
# Converted JS36156.mat to CSV.
# Converted JS16286.mat to CSV.
# Converted JS39265.mat to CSV.
# Converted JS26345.mat to CSV.
# Converted JS31639.mat to CSV.
# Converted JS06095.mat to CSV.
# Converted JS29076.mat to CSV.
# Converted JS32330.mat to CSV.
# Converted JS34999.mat to CSV.
# Converted JS14491.mat to CSV.
# Converted JS25894.mat to CSV.
# Converted JS15957.mat to CSV.
# Converted JS04682.mat to CSV.
# Converted JS32324.mat to CSV.
# Converted JS05588.mat to CSV.
# Converted JS25658.mat to CSV.
# Converted JS22137.mat to CSV.
# Converted JS14485.mat to CSV.
# Converted JS25880.mat to CSV.
# Converted JS04696.mat to CSV.
# Converted JS15943.mat to CSV.
# Converted JS01936.mat to CSV.
# Converted JS30533.mat to CSV.
# Converted JS20720.mat to CSV.
# Converted JS36142.mat to CSV.
# Converted JS39271.mat to CSV.
# Converted JS16292.mat to CSV.
# Converted JS26351.mat to CSV.
# Converted JS29062.mat to CSV.
# Converted JS06081.mat to CSV.
# Converted JS26437.mat to CSV.
# Converted JS17832.mat to CSV.
# Converted JS29704.mat to CSV.
# Converted JS36624.mat to CSV.
# Converted JS08912.mat to CSV.
# Converted JS01088.mat to CSV.
# Converted JS21358.mat to CSV.
# Converted JS39517.mat to CSV.
# Converted JS00396.mat to CSV.
# Converted JS38609.mat to CSV.
# Converted JS27729.mat to CSV.
# Converted JS10185.mat to CSV.
# Converted JS30255.mat to CSV.
# Converted JS22889.mat to CSV.
# Converted JS34033.mat to CSV.
# Converted JS33984.mat to CSV.
# Converted JS22651.mat to CSV.
# Converted JS02581.mat to CSV.
# Converted JS32442.mat to CSV.
# Converted JS12792.mat to CSV.
# Converted JS03847.mat to CSV.
# Converted JS31163.mat to CSV.
# Converted JS21370.mat to CSV.
# Converted JS40942.mat to CSV.
# Converted JS38621.mat to CSV.
# Converted JS06917.mat to CSV.
# Converted JS37512.mat to CSV.
# Converted JS28432.mat to CSV.
# Converted JS41484.mat to CSV.
# Converted JS19837.mat to CSV.
# Converted JS27701.mat to CSV.
# Converted JS33774.mat to CSV.
# Converted JS12962.mat to CSV.
# Converted JS23567.mat to CSV.
# Converted JS35305.mat to CSV.
# Converted JS22679.mat to CSV.
# Converted JS25116.mat to CSV.
# Converted JS43293.mat to CSV.
# Converted JS25670.mat to CSV.
# Converted JS35463.mat to CSV.
# Converted JS42833.mat to CSV.
# Converted JS04866.mat to CSV.
# Converted JS45184.mat to CSV.
# Converted JS33012.mat to CSV.
# Converted JS28354.mat to CSV.
# Converted JS08084.mat to CSV.
# Converted JS27067.mat to CSV.
# Converted JS20708.mat to CSV.
# Converted JS38147.mat to CSV.
# Converted JS18297.mat to CSV.
# Converted JS37274.mat to CSV.
# Converted JS39259.mat to CSV.
# Converted JS21416.mat to CSV.
# Converted JS10813.mat to CSV.
# Converted JS31605.mat to CSV.
# Converted JS26379.mat to CSV.
# Converted JS28340.mat to CSV.
# Converted JS27073.mat to CSV.
# Converted JS08090.mat to CSV.
# Converted JS38153.mat to CSV.
# Converted JS37260.mat to CSV.
# Converted JS18283.mat to CSV.
# Converted JS21402.mat to CSV.
# Converted JS10807.mat to CSV.
# Converted JS31611.mat to CSV.
# Converted JS25664.mat to CSV.
# Converted JS32318.mat to CSV.
# Converted JS35477.mat to CSV.
# Converted JS04872.mat to CSV.
# Converted JS42827.mat to CSV.
# Converted JS45190.mat to CSV.
# Converted JS33006.mat to CSV.
# Converted JS33760.mat to CSV.
# Converted JS42199.mat to CSV.
# Converted JS12976.mat to CSV.
# Converted JS23573.mat to CSV.
# Converted JS35311.mat to CSV.
# Converted JS25102.mat to CSV.
# Converted JS43287.mat to CSV.
# Converted JS29738.mat to CSV.
# Converted JS31177.mat to CSV.
# Converted JS21364.mat to CSV.
# Converted JS36618.mat to CSV.
# Converted JS06903.mat to CSV.
# Converted JS38635.mat to CSV.
# Converted JS40956.mat to CSV.
# Converted JS37506.mat to CSV.
# Converted JS41490.mat to CSV.
# Converted JS30269.mat to CSV.
# Converted JS28426.mat to CSV.
# Converted JS27715.mat to CSV.
# Converted JS19823.mat to CSV.
# Converted JS00341.mat to CSV.
# Converted JS20091.mat to CSV.
# Converted JS10152.mat to CSV.
# Converted JS30282.mat to CSV.
# Converted JS09403.mat to CSV.
# Converted JS06730.mat to CSV.
# Converted JS38806.mat to CSV.
# Converted JS27926.mat to CSV.
# Converted JS19610.mat to CSV.
# Converted JS16523.mat to CSV.
# Converted JS22686.mat to CSV.
# Converted JS33953.mat to CSV.
# Converted JS02556.mat to CSV.
# Converted JS44503.mat to CSV.
# Converted JS32495.mat to CSV.
# Converted JS05239.mat to CSV.
# Converted JS03890.mat to CSV.
# Converted JS12745.mat to CSV.
# Converted JS04127.mat to CSV.
# Converted JS42172.mat to CSV.
# Converted JS23598.mat to CSV.
# Converted JS14334.mat to CSV.
# Converted JS03648.mat to CSV.
# Converted JS14452.mat to CSV.
# Converted JS34782.mat to CSV.
# Converted JS25857.mat to CSV.
# Converted JS15994.mat to CSV.
# Converted JS04641.mat to CSV.
# Converted JS42614.mat to CSV.
# Converted JS12023.mat to CSV.
# Converted JS04899.mat to CSV.
# Converted JS02230.mat to CSV.
# Converted JS44265.mat to CSV.
# Converted JS36195.mat to CSV.
# Converted JS01739.mat to CSV.
# Converted JS16245.mat to CSV.
# Converted JS09365.mat to CSV.
# Converted JS26386.mat to CSV.
# Converted JS06056.mat to CSV.
# Converted JS40003.mat to CSV.
# Converted JS27098.mat to CSV.
# Converted JS10634.mat to CSV.
# Converted JS07348.mat to CSV.
# Converted JS00427.mat to CSV.
# Converted JS18268.mat to CSV.
# Converted JS31822.mat to CSV.
# Converted JS36181.mat to CSV.
# Converted JS19162.mat to CSV.
# Converted JS16251.mat to CSV.
# Converted JS26392.mat to CSV.
# Converted JS09371.mat to CSV.
# Converted JS40017.mat to CSV.
# Converted JS06042.mat to CSV.
# Converted JS10620.mat to CSV.
# Converted JS41309.mat to CSV.
# Converted JS00433.mat to CSV.
# Converted JS31836.mat to CSV.
# Converted JS14446.mat to CSV.
# Converted JS25843.mat to CSV.
# Converted JS34796.mat to CSV.
# Converted JS42600.mat to CSV.
# Converted JS04655.mat to CSV.
# Converted JS15980.mat to CSV.
# Converted JS13329.mat to CSV.
# Converted JS12037.mat to CSV.
# Converted JS15758.mat to CSV.
# Converted JS44271.mat to CSV.
# Converted JS35488.mat to CSV.
# Converted JS02224.mat to CSV.
# Converted JS33947.mat to CSV.
# Converted JS22692.mat to CSV.
# Converted JS44517.mat to CSV.
# Converted JS02542.mat to CSV.
# Converted JS43278.mat to CSV.
# Converted JS32481.mat to CSV.
# Converted JS12751.mat to CSV.
# Converted JS03884.mat to CSV.
# Converted JS42166.mat to CSV.
# Converted JS04133.mat to CSV.
# Converted JS14320.mat to CSV.
# Converted JS12989.mat to CSV.
# Converted JS00355.mat to CSV.
# Converted JS20085.mat to CSV.
# Converted JS17629.mat to CSV.
# Converted JS10146.mat to CSV.
# Converted JS08709.mat to CSV.
# Converted JS30296.mat to CSV.
# Converted JS09417.mat to CSV.
# Converted JS11258.mat to CSV.
# Converted JS31188.mat to CSV.
# Converted JS40771.mat to CSV.
# Converted JS38812.mat to CSV.
# Converted JS06724.mat to CSV.
# Converted JS19604.mat to CSV.
# Converted JS27932.mat to CSV.
# Converted JS16537.mat to CSV.
# Converted JS15016.mat to CSV.
# Converted JS12779.mat to CSV.
# Converted JS43250.mat to CSV.
# Converted JS05205.mat to CSV.
# Converted JS13467.mat to CSV.
# Converted JS22862.mat to CSV.
# Converted JS03674.mat to CSV.
# Converted JS14308.mat to CSV.
# Converted JS17601.mat to CSV.
# Converted JS29937.mat to CSV.
# Converted JS40981.mat to CSV.
# Converted JS18532.mat to CSV.
# Converted JS41447.mat to CSV.
# Converted JS07412.mat to CSV.
# Converted JS36817.mat to CSV.
# Converted JS08721.mat to CSV.
# Converted JS40759.mat to CSV.
# Converted JS11270.mat to CSV.
# Converted JS01063.mat to CSV.
# Converted JS16279.mat to CSV.
# Converted JS01705.mat to CSV.
# Converted JS29089.mat to CSV.
# Converted JS09359.mat to CSV.
# Converted JS41321.mat to CSV.
# Converted JS07374.mat to CSV.
# Converted JS28397.mat to CSV.
# Converted JS08047.mat to CSV.
# Converted JS10608.mat to CSV.
# Converted JS17167.mat to CSV.
# Converted JS38184.mat to CSV.
# Converted JS18254.mat to CSV.
# Converted JS45147.mat to CSV.
# Converted JS03112.mat to CSV.
# Converted JS13301.mat to CSV.
# Converted JS42628.mat to CSV.
# Converted JS34966.mat to CSV.
# Converted JS43536.mat to CSV.
# Converted JS05563.mat to CSV.
# Converted JS44259.mat to CSV.
# Converted JS15770.mat to CSV.
# Converted JS03106.mat to CSV.
# Converted JS45153.mat to CSV.
# Converted JS13315.mat to CSV.
# Converted JS04669.mat to CSV.
# Converted JS34972.mat to CSV.
# Converted JS05577.mat to CSV.
# Converted JS43522.mat to CSV.
# Converted JS02218.mat to CSV.
# Converted JS15764.mat to CSV.
# Converted JS01711.mat to CSV.
# Converted JS11502.mat to CSV.
# Converted JS28383.mat to CSV.
# Converted JS07360.mat to CSV.
# Converted JS41335.mat to CSV.
# Converted JS38190.mat to CSV.
# Converted JS17173.mat to CSV.
# Converted JS18240.mat to CSV.
# Converted JS40995.mat to CSV.
# Converted JS29923.mat to CSV.
# Converted JS17615.mat to CSV.
# Converted JS18526.mat to CSV.
# Converted JS00369.mat to CSV.
# Converted JS07406.mat to CSV.
# Converted JS41453.mat to CSV.
# Converted JS08735.mat to CSV.
# Converted JS36803.mat to CSV.
# Converted JS06718.mat to CSV.
# Converted JS11264.mat to CSV.
# Converted JS01077.mat to CSV.
# Converted JS19638.mat to CSV.
# Converted JS15002.mat to CSV.
# Converted JS05211.mat to CSV.
# Converted JS43244.mat to CSV.
# Converted JS13473.mat to CSV.
# Converted JS22876.mat to CSV.
# Converted JS03660.mat to CSV.
# Converted JS24750.mat to CSV.
# Converted JS35885.mat to CSV.
# Converted JS43913.mat to CSV.
# Converted JS05946.mat to CSV.
# Converted JS14693.mat to CSV.
# Converted JS24988.mat to CSV.
# Converted JS22321.mat to CSV.
# Converted JS32132.mat to CSV.
# Converted JS06297.mat to CSV.
# Converted JS29274.mat to CSV.
# Converted JS26147.mat to CSV.
# Converted JS21628.mat to CSV.
# Converted JS16084.mat to CSV.
# Converted JS39067.mat to CSV.
# Converted JS36354.mat to CSV.
# Converted JS38379.mat to CSV.
# Converted JS20536.mat to CSV.
# Converted JS11933.mat to CSV.
# Converted JS30725.mat to CSV.
# Converted JS07189.mat to CSV.
# Converted JS27259.mat to CSV.
# Converted JS30043.mat to CSV.
# Converted JS10393.mat to CSV.
# Converted JS00180.mat to CSV.
# Converted JS41862.mat to CSV.
# Converted JS39701.mat to CSV.
# Converted JS07837.mat to CSV.
# Converted JS36432.mat to CSV.
# Converted JS29512.mat to CSV.
# Converted JS18917.mat to CSV.
# Converted JS26621.mat to CSV.
# Converted JS25328.mat to CSV.
# Converted JS12584.mat to CSV.
# Converted JS32654.mat to CSV.
# Converted JS23981.mat to CSV.
# Converted JS13842.mat to CSV.
# Converted JS02797.mat to CSV.
# Converted JS34225.mat to CSV.
# Converted JS03489.mat to CSV.
# Converted JS23759.mat to CSV.
# Converted JS24036.mat to CSV.
# Converted JS12590.mat to CSV.
# Converted JS23995.mat to CSV.
# Converted JS32640.mat to CSV.
# Converted JS02783.mat to CSV.
# Converted JS13856.mat to CSV.
# Converted JS22453.mat to CSV.
# Converted JS34231.mat to CSV.
# Converted JS32898.mat to CSV.
# Converted JS24022.mat to CSV.
# Converted JS28618.mat to CSV.
# Converted JS30057.mat to CSV.
# Converted JS10387.mat to CSV.
# Converted JS20244.mat to CSV.
# Converted JS37738.mat to CSV.
# Converted JS00194.mat to CSV.
# Converted JS07823.mat to CSV.
# Converted JS39715.mat to CSV.
# Converted JS41876.mat to CSV.
# Converted JS36426.mat to CSV.
# Converted JS31349.mat to CSV.
# Converted JS29506.mat to CSV.
# Converted JS26635.mat to CSV.
# Converted JS18903.mat to CSV.
# Converted JS11099.mat to CSV.
# Converted JS29260.mat to CSV.
# Converted JS06283.mat to CSV.
# Converted JS26153.mat to CSV.
# Converted JS39073.mat to CSV.
# Converted JS16090.mat to CSV.
# Converted JS36340.mat to CSV.
# Converted JS20522.mat to CSV.
# Converted JS11927.mat to CSV.
# Converted JS30731.mat to CSV.
# Converted JS35891.mat to CSV.
# Converted JS24744.mat to CSV.
# Converted JS33238.mat to CSV.
# Converted JS04494.mat to CSV.
# Converted JS14687.mat to CSV.
# Converted JS05952.mat to CSV.
# Converted JS43907.mat to CSV.
# Converted JS35649.mat to CSV.
# Converted JS22335.mat to CSV.
# Converted JS15599.mat to CSV.
# Converted JS32126.mat to CSV.
# Converted JS09198.mat to CSV.
# Converted JS29248.mat to CSV.
# Converted JS31407.mat to CSV.
# Converted JS36368.mat to CSV.
# Converted JS21614.mat to CSV.
# Converted JS18095.mat to CSV.
# Converted JS37076.mat to CSV.
# Converted JS38345.mat to CSV.
# Converted JS08286.mat to CSV.
# Converted JS27265.mat to CSV.
# Converted JS30719.mat to CSV.
# Converted JS28156.mat to CSV.
# Converted JS33210.mat to CSV.
# Converted JS35661.mat to CSV.
# Converted JS44098.mat to CSV.
# Converted JS14877.mat to CSV.
# Converted JS25472.mat to CSV.
# Converted JS32668.mat to CSV.
# Converted JS43091.mat to CSV.
# Converted JS25314.mat to CSV.
# Converted JS35107.mat to CSV.
# Converted JS23765.mat to CSV.
# Converted JS34219.mat to CSV.
# Converted JS33576.mat to CSV.
# Converted JS02973.mat to CSV.
# Converted JS44926.mat to CSV.
# Converted JS27503.mat to CSV.
# Converted JS41686.mat to CSV.
# Converted JS16906.mat to CSV.
# Converted JS09826.mat to CSV.
# Converted JS37710.mat to CSV.
# Converted JS38423.mat to CSV.
# Converted JS21172.mat to CSV.
# Converted JS40598.mat to CSV.
# Converted JS31361.mat to CSV.
# Converted JS27517.mat to CSV.
# Converted JS16912.mat to CSV.
# Converted JS28624.mat to CSV.
# Converted JS41692.mat to CSV.
# Converted JS37704.mat to CSV.
# Converted JS09832.mat to CSV.
# Converted JS20278.mat to CSV.
# Converted JS38437.mat to CSV.
# Converted JS39729.mat to CSV.
# Converted JS21166.mat to CSV.
# Converted JS26609.mat to CSV.
# Converted JS31375.mat to CSV.
# Converted JS43085.mat to CSV.
# Converted JS25300.mat to CSV.
# Converted JS35113.mat to CSV.
# Converted JS23771.mat to CSV.
# Converted JS33562.mat to CSV.
# Converted JS44932.mat to CSV.
# Converted JS02967.mat to CSV.
# Converted JS33204.mat to CSV.
# Converted JS24778.mat to CSV.
# Converted JS23017.mat to CSV.
# Converted JS22309.mat to CSV.
# Converted JS35675.mat to CSV.
# Converted JS14863.mat to CSV.
# Converted JS25466.mat to CSV.
# Converted JS00816.mat to CSV.
# Converted JS31413.mat to CSV.
# Converted JS21600.mat to CSV.
# Converted JS37062.mat to CSV.
# Converted JS18081.mat to CSV.
# Converted JS38351.mat to CSV.
# Converted JS27271.mat to CSV.
# Converted JS08292.mat to CSV.
# Converted JS28142.mat to CSV.
# Converted JS17359.mat to CSV.
# Converted JS37089.mat to CSV.
# Converted JS00625.mat to CSV.
# Converted JS21833.mat to CSV.
# Converted JS10436.mat to CSV.
# Converted JS08279.mat to CSV.
# Converted JS40201.mat to CSV.
# Converted JS06254.mat to CSV.
# Converted JS09167.mat to CSV.
# Converted JS26184.mat to CSV.
# Converted JS11728.mat to CSV.
# Converted JS16047.mat to CSV.
# Converted JS19374.mat to CSV.
# Converted JS36397.mat to CSV.
# Converted JS44067.mat to CSV.
# Converted JS02032.mat to CSV.
# Converted JS12221.mat to CSV.
# Converted JS14888.mat to CSV.
# Converted JS43708.mat to CSV.
# Converted JS24793.mat to CSV.
# Converted JS35846.mat to CSV.
# Converted JS42416.mat to CSV.
# Converted JS04443.mat to CSV.
# Converted JS45379.mat to CSV.
# Converted JS05985.mat to CSV.
# Converted JS14650.mat to CSV.
# Converted JS14136.mat to CSV.
# Converted JS13659.mat to CSV.
# Converted JS42370.mat to CSV.
# Converted JS33589.mat to CSV.
# Converted JS04325.mat to CSV.
# Converted JS12547.mat to CSV.
# Converted JS32697.mat to CSV.
# Converted JS23942.mat to CSV.
# Converted JS44701.mat to CSV.
# Converted JS13881.mat to CSV.
# Converted JS02754.mat to CSV.
# Converted JS22484.mat to CSV.
# Converted JS15228.mat to CSV.
# Converted JS16721.mat to CSV.
# Converted JS28817.mat to CSV.
# Converted JS19412.mat to CSV.
# Converted JS40567.mat to CSV.
# Converted JS06532.mat to CSV.
# Converted JS37937.mat to CSV.
# Converted JS09601.mat to CSV.
# Converted JS30080.mat to CSV.
# Converted JS41679.mat to CSV.
# Converted JS10350.mat to CSV.
# Converted JS20293.mat to CSV.
# Converted JS00143.mat to CSV.
# Converted JS21199.mat to CSV.
# Converted JS28803.mat to CSV.
# Converted JS16735.mat to CSV.
# Converted JS19406.mat to CSV.
# Converted JS01249.mat to CSV.
# Converted JS06526.mat to CSV.
# Converted JS40573.mat to CSV.
# Converted JS09615.mat to CSV.
# Converted JS37923.mat to CSV.
# Converted JS30094.mat to CSV.
# Converted JS07638.mat to CSV.
# Converted JS10344.mat to CSV.
# Converted JS20287.mat to CSV.
# Converted JS00157.mat to CSV.
# Converted JS18718.mat to CSV.
# Converted JS14122.mat to CSV.
# Converted JS02998.mat to CSV.
# Converted JS42364.mat to CSV.
# Converted JS12553.mat to CSV.
# Converted JS23956.mat to CSV.
# Converted JS32683.mat to CSV.
# Converted JS02740.mat to CSV.
# Converted JS13895.mat to CSV.
# Converted JS44715.mat to CSV.
# Converted JS22490.mat to CSV.
# Converted JS02026.mat to CSV.
# Converted JS44073.mat to CSV.
# Converted JS25499.mat to CSV.
# Converted JS12235.mat to CSV.
# Converted JS05749.mat to CSV.
# Converted JS35852.mat to CSV.
# Converted JS24787.mat to CSV.
# Converted JS04457.mat to CSV.
# Converted JS42402.mat to CSV.
# Converted JS03338.mat to CSV.
# Converted JS14644.mat to CSV.
# Converted JS05991.mat to CSV.
# Converted JS00631.mat to CSV.
# Converted JS21827.mat to CSV.
# Converted JS10422.mat to CSV.
# Converted JS40215.mat to CSV.
# Converted JS26190.mat to CSV.
# Converted JS09173.mat to CSV.
# Converted JS16053.mat to CSV.
# Converted JS36383.mat to CSV.
# Converted JS19360.mat to CSV.
# Converted JS15572.mat to CSV.
# Converted JS24977.mat to CSV.
# Converted JS05761.mat to CSV.
# Converted JS43734.mat to CSV.
# Converted JS13103.mat to CSV.
# Converted JS03310.mat to CSV.
# Converted JS45345.mat to CSV.
# Converted JS18056.mat to CSV.
# Converted JS00619.mat to CSV.
# Converted JS17365.mat to CSV.
# Converted JS38386.mat to CSV.
# Converted JS08245.mat to CSV.
# Converted JS28195.mat to CSV.
# Converted JS41123.mat to CSV.
# Converted JS11714.mat to CSV.
# Converted JS06268.mat to CSV.
# Converted JS01507.mat to CSV.
# Converted JS19348.mat to CSV.
# Converted JS39098.mat to CSV.
# Converted JS30902.mat to CSV.
# Converted JS01261.mat to CSV.
# Converted JS11072.mat to CSV.
# Converted JS08523.mat to CSV.
# Converted JS07610.mat to CSV.
# Converted JS39926.mat to CSV.
# Converted JS41645.mat to CSV.
# Converted JS26806.mat to CSV.
# Converted JS18730.mat to CSV.
# Converted JS17403.mat to CSV.
# Converted JS32873.mat to CSV.
# Converted JS03476.mat to CSV.
# Converted JS04319.mat to CSV.
# Converted JS13665.mat to CSV.
# Converted JS05007.mat to CSV.
# Converted JS43052.mat to CSV.
# Converted JS15214.mat to CSV.
# Converted JS32867.mat to CSV.
# Converted JS03462.mat to CSV.
# Converted JS42358.mat to CSV.
# Converted JS13671.mat to CSV.
# Converted JS43046.mat to CSV.
# Converted JS05013.mat to CSV.
# Converted JS15200.mat to CSV.
# Converted JS44729.mat to CSV.
# Converted JS01275.mat to CSV.
# Converted JS41889.mat to CSV.
# Converted JS16709.mat to CSV.
# Converted JS11066.mat to CSV.
# Converted JS09629.mat to CSV.
# Converted JS08537.mat to CSV.
# Converted JS10378.mat to CSV.
# Converted JS41651.mat to CSV.
# Converted JS39932.mat to CSV.
# Converted JS18724.mat to CSV.
# Converted JS26812.mat to CSV.
# Converted JS17417.mat to CSV.
# Converted JS18042.mat to CSV.
# Converted JS38392.mat to CSV.
# Converted JS17371.mat to CSV.
# Converted JS08251.mat to CSV.
# Converted JS41137.mat to CSV.
# Converted JS28181.mat to CSV.
# Converted JS07162.mat to CSV.
# Converted JS11700.mat to CSV.
# Converted JS40229.mat to CSV.
# Converted JS01513.mat to CSV.
# Converted JS30916.mat to CSV.
# Converted JS15566.mat to CSV.
# Converted JS24963.mat to CSV.
# Converted JS43720.mat to CSV.
# Converted JS05775.mat to CSV.
# Converted JS12209.mat to CSV.
# Converted JS13117.mat to CSV.
# Converted JS14678.mat to CSV.
# Converted JS45351.mat to CSV.
# Converted JS03304.mat to CSV.
# Converted JS12396.mat to CSV.
# Converted JS32046.mat to CSV.
# Converted JS35729.mat to CSV.
# Converted JS02185.mat to CSV.
# Converted JS22255.mat to CSV.
# Converted JS34437.mat to CSV.
# Converted JS05832.mat to CSV.
# Converted JS43867.mat to CSV.
# Converted JS13088.mat to CSV.
# Converted JS33358.mat to CSV.
# Converted JS30651.mat to CSV.
# Converted JS21984.mat to CSV.
# Converted JS10581.mat to CSV.
# Converted JS20442.mat to CSV.
# Converted JS11847.mat to CSV.
# Converted JS00792.mat to CSV.
# Converted JS39113.mat to CSV.
# Converted JS30889.mat to CSV.
# Converted JS36220.mat to CSV.
# Converted JS29300.mat to CSV.
# Converted JS26033.mat to CSV.
# Converted JS31229.mat to CSV.
# Converted JS29466.mat to CSV.
# Converted JS06485.mat to CSV.
# Converted JS26755.mat to CSV.
# Converted JS18863.mat to CSV.
# Converted JS37880.mat to CSV.
# Converted JS07943.mat to CSV.
# Converted JS39675.mat to CSV.
# Converted JS16696.mat to CSV.
# Converted JS41916.mat to CSV.
# Converted JS36546.mat to CSV.
# Converted JS20324.mat to CSV.
# Converted JS17588.mat to CSV.
# Converted JS37658.mat to CSV.
# Converted JS28778.mat to CSV.
# Converted JS30137.mat to CSV.
# Converted JS24142.mat to CSV.
# Converted JS04292.mat to CSV.
# Converted JS34351.mat to CSV.
# Converted JS14081.mat to CSV.
# Converted JS13936.mat to CSV.
# Converted JS22533.mat to CSV.
# Converted JS32720.mat to CSV.
# Converted JS24156.mat to CSV.
# Converted JS04286.mat to CSV.
# Converted JS34345.mat to CSV.
# Converted JS23639.mat to CSV.
# Converted JS14095.mat to CSV.
# Converted JS13922.mat to CSV.
# Converted JS22527.mat to CSV.
# Converted JS25248.mat to CSV.
# Converted JS32734.mat to CSV.
# Converted JS05198.mat to CSV.
# Converted JS06491.mat to CSV.
# Converted JS29472.mat to CSV.
# Converted JS37894.mat to CSV.
# Converted JS18877.mat to CSV.
# Converted JS26741.mat to CSV.
# Converted JS41902.mat to CSV.
# Converted JS16682.mat to CSV.
# Converted JS39661.mat to CSV.
# Converted JS07957.mat to CSV.
# Converted JS36552.mat to CSV.
# Converted JS20330.mat to CSV.
# Converted JS26999.mat to CSV.
# Converted JS30123.mat to CSV.
# Converted JS21990.mat to CSV.
# Converted JS30645.mat to CSV.
# Converted JS27339.mat to CSV.
# Converted JS10595.mat to CSV.
# Converted JS38219.mat to CSV.
# Converted JS20456.mat to CSV.
# Converted JS00786.mat to CSV.
# Converted JS11853.mat to CSV.
# Converted JS21748.mat to CSV.
# Converted JS39107.mat to CSV.
# Converted JS36234.mat to CSV.
# Converted JS01498.mat to CSV.
# Converted JS29314.mat to CSV.
# Converted JS26027.mat to CSV.
# Converted JS12382.mat to CSV.
# Converted JS32052.mat to CSV.
# Converted JS02191.mat to CSV.
# Converted JS22241.mat to CSV.
# Converted JS34423.mat to CSV.
# Converted JS43873.mat to CSV.
# Converted JS05826.mat to CSV.
# Converted JS27311.mat to CSV.
# Converted JS28022.mat to CSV.
# Converted JS41094.mat to CSV.
# Converted JS37102.mat to CSV.
# Converted JS38231.mat to CSV.
# Converted JS21760.mat to CSV.
# Converted JS00976.mat to CSV.
# Converted JS31573.mat to CSV.
# Converted JS14903.mat to CSV.
# Converted JS43683.mat to CSV.
# Converted JS25506.mat to CSV.
# Converted JS22269.mat to CSV.
# Converted JS35715.mat to CSV.
# Converted JS33364.mat to CSV.
# Converted JS33402.mat to CSV.
# Converted JS44852.mat to CSV.
# Converted JS02807.mat to CSV.
# Converted JS23611.mat to CSV.
# Converted JS35073.mat to CSV.
# Converted JS25260.mat to CSV.
# Converted JS26769.mat to CSV.
# Converted JS31215.mat to CSV.
# Converted JS19599.mat to CSV.
# Converted JS39649.mat to CSV.
# Converted JS37664.mat to CSV.
# Converted JS18687.mat to CSV.
# Converted JS09952.mat to CSV.
# Converted JS20318.mat to CSV.
# Converted JS38557.mat to CSV.
# Converted JS27477.mat to CSV.
# Converted JS08494.mat to CSV.
# Converted JS16872.mat to CSV.
# Converted JS39891.mat to CSV.
# Converted JS28744.mat to CSV.
# Converted JS31201.mat to CSV.
# Converted JS28988.mat to CSV.
# Converted JS09946.mat to CSV.
# Converted JS18693.mat to CSV.
# Converted JS37670.mat to CSV.
# Converted JS38543.mat to CSV.
# Converted JS08480.mat to CSV.
# Converted JS27463.mat to CSV.
# Converted JS28750.mat to CSV.
# Converted JS39885.mat to CSV.
# Converted JS16866.mat to CSV.
# Converted JS33416.mat to CSV.
# Converted JS02813.mat to CSV.
# Converted JS44846.mat to CSV.
# Converted JS23605.mat to CSV.
# Converted JS34379.mat to CSV.
# Converted JS35067.mat to CSV.
# Converted JS32708.mat to CSV.
# Converted JS25274.mat to CSV.
# Converted JS43697.mat to CSV.
# Converted JS14917.mat to CSV.
# Converted JS25512.mat to CSV.
# Converted JS35701.mat to CSV.
# Converted JS42589.mat to CSV.
# Converted JS33370.mat to CSV.
# Converted JS27305.mat to CSV.
# Converted JS30679.mat to CSV.
# Converted JS41080.mat to CSV.
# Converted JS28036.mat to CSV.
# Converted JS37116.mat to CSV.
# Converted JS38225.mat to CSV.
# Converted JS36208.mat to CSV.
# Converted JS21774.mat to CSV.
# Converted JS00962.mat to CSV.
# Converted JS29328.mat to CSV.
# Converted JS31567.mat to CSV.
# Converted JS16133.mat to CSV.
# Converted JS19200.mat to CSV.
# Converted JS06320.mat to CSV.
# Converted JS40375.mat to CSV.
# Converted JS00989.mat to CSV.
# Converted JS09013.mat to CSV.
# Converted JS30692.mat to CSV.
# Converted JS21947.mat to CSV.
# Converted JS10542.mat to CSV.
# Converted JS20481.mat to CSV.
# Converted JS11884.mat to CSV.
# Converted JS00751.mat to CSV.
# Converted JS03258.mat to CSV.
# Converted JS14724.mat to CSV.
# Converted JS35932.mat to CSV.
# Converted JS04537.mat to CSV.
# Converted JS42562.mat to CSV.
# Converted JS12355.mat to CSV.
# Converted JS32085.mat to CSV.
# Converted JS05629.mat to CSV.
# Converted JS02146.mat to CSV.
# Converted JS44113.mat to CSV.
# Converted JS02620.mat to CSV.
# Converted JS44675.mat to CSV.
# Converted JS12433.mat to CSV.
# Converted JS23836.mat to CSV.
# Converted JS24181.mat to CSV.
# Converted JS04251.mat to CSV.
# Converted JS42204.mat to CSV.
# Converted JS34392.mat to CSV.
# Converted JS14042.mat to CSV.
# Converted JS00037.mat to CSV.
# Converted JS18678.mat to CSV.
# Converted JS27488.mat to CSV.
# Converted JS10224.mat to CSV.
# Converted JS06446.mat to CSV.
# Converted JS40413.mat to CSV.
# Converted JS26796.mat to CSV.
# Converted JS09775.mat to CSV.
# Converted JS37843.mat to CSV.
# Converted JS07980.mat to CSV.
# Converted JS28963.mat to CSV.
# Converted JS16655.mat to CSV.
# Converted JS36585.mat to CSV.
# Converted JS19566.mat to CSV.
# Converted JS01329.mat to CSV.
# Converted JS00023.mat to CSV.
# Converted JS16899.mat to CSV.
# Converted JS41719.mat to CSV.
# Converted JS10230.mat to CSV.
# Converted JS40407.mat to CSV.
# Converted JS06452.mat to CSV.
# Converted JS37857.mat to CSV.
# Converted JS09761.mat to CSV.
# Converted JS26782.mat to CSV.
# Converted JS16641.mat to CSV.
# Converted JS28977.mat to CSV.
# Converted JS07994.mat to CSV.
# Converted JS19572.mat to CSV.
# Converted JS36591.mat to CSV.
# Converted JS35098.mat to CSV.
# Converted JS44661.mat to CSV.
# Converted JS02634.mat to CSV.
# Converted JS15348.mat to CSV.
# Converted JS12427.mat to CSV.
# Converted JS23822.mat to CSV.
# Converted JS24195.mat to CSV.
# Converted JS13739.mat to CSV.
# Converted JS42210.mat to CSV.
# Converted JS04245.mat to CSV.
# Converted JS34386.mat to CSV.
# Converted JS14056.mat to CSV.
# Converted JS45219.mat to CSV.
# Converted JS14730.mat to CSV.
# Converted JS35926.mat to CSV.
# Converted JS42576.mat to CSV.
# Converted JS04523.mat to CSV.
# Converted JS12341.mat to CSV.
# Converted JS32091.mat to CSV.
# Converted JS43668.mat to CSV.
# Converted JS44107.mat to CSV.
# Converted JS02152.mat to CSV.
# Converted JS22282.mat to CSV.
# Converted JS16127.mat to CSV.
# Converted JS19214.mat to CSV.
# Converted JS40361.mat to CSV.
# Converted JS31598.mat to CSV.
# Converted JS06334.mat to CSV.
# Converted JS09007.mat to CSV.
# Converted JS11648.mat to CSV.
# Converted JS21953.mat to CSV.
# Converted JS30686.mat to CSV.
# Converted JS10556.mat to CSV.
# Converted JS08319.mat to CSV.
# Converted JS20495.mat to CSV.
# Converted JS17239.mat to CSV.
# Converted JS00745.mat to CSV.
# Converted JS11890.mat to CSV.
# Converted JS43898.mat to CSV.
# Converted JS14718.mat to CSV.
# Converted JS45231.mat to CSV.
# Converted JS03264.mat to CSV.
# Converted JS13077.mat to CSV.
# Converted JS43640.mat to CSV.
# Converted JS05615.mat to CSV.
# Converted JS12369.mat to CSV.
# Converted JS15406.mat to CSV.
# Converted JS24803.mat to CSV.
# Converted JS01473.mat to CSV.
# Converted JS30876.mat to CSV.
# Converted JS11660.mat to CSV.
# Converted JS40349.mat to CSV.
# Converted JS08331.mat to CSV.
# Converted JS41057.mat to CSV.
# Converted JS07002.mat to CSV.
# Converted JS18122.mat to CSV.
# Converted JS17211.mat to CSV.
# Converted JS18644.mat to CSV.
# Converted JS09991.mat to CSV.
# Converted JS26972.mat to CSV.
# Converted JS38594.mat to CSV.
# Converted JS17577.mat to CSV.
# Converted JS08457.mat to CSV.
# Converted JS10218.mat to CSV.
# Converted JS41731.mat to CSV.
# Converted JS39852.mat to CSV.
# Converted JS28787.mat to CSV.
# Converted JS07764.mat to CSV.
# Converted JS11106.mat to CSV.
# Converted JS09749.mat to CSV.
# Converted JS29499.mat to CSV.
# Converted JS01315.mat to CSV.
# Converted JS16669.mat to CSV.
# Converted JS15360.mat to CSV.
# Converted JS44649.mat to CSV.
# Converted JS43126.mat to CSV.
# Converted JS05173.mat to CSV.
# Converted JS42238.mat to CSV.
# Converted JS13711.mat to CSV.
# Converted JS44891.mat to CSV.
# Converted JS32907.mat to CSV.
# Converted JS03502.mat to CSV.
# Converted JS15374.mat to CSV.
# Converted JS02608.mat to CSV.
# Converted JS05167.mat to CSV.
# Converted JS43132.mat to CSV.
# Converted JS04279.mat to CSV.
# Converted JS44885.mat to CSV.
# Converted JS13705.mat to CSV.
# Converted JS32913.mat to CSV.
# Converted JS45543.mat to CSV.
# Converted JS26966.mat to CSV.
# Converted JS09985.mat to CSV.
# Converted JS18650.mat to CSV.
# Converted JS17563.mat to CSV.
# Converted JS38580.mat to CSV.
# Converted JS08443.mat to CSV.
# Converted JS07770.mat to CSV.
# Converted JS28793.mat to CSV.
# Converted JS39846.mat to CSV.
# Converted JS41725.mat to CSV.
# Converted JS18888.mat to CSV.
# Converted JS11112.mat to CSV.
# Converted JS01301.mat to CSV.
# Converted JS01467.mat to CSV.
# Converted JS19228.mat to CSV.
# Converted JS30862.mat to CSV.
# Converted JS06308.mat to CSV.
# Converted JS08325.mat to CSV.
# Converted JS07016.mat to CSV.
# Converted JS41043.mat to CSV.
# Converted JS18136.mat to CSV.
# Converted JS00779.mat to CSV.
# Converted JS17205.mat to CSV.
# Converted JS03270.mat to CSV.
# Converted JS45225.mat to CSV.
# Converted JS13063.mat to CSV.
# Converted JS05601.mat to CSV.
# Converted JS43654.mat to CSV.
# Converted JS15412.mat to CSV.
# Converted JS24817.mat to CSV.
# Converted JS32522.mat to CSV.
# Converted JS03927.mat to CSV.
# Converted JS22731.mat to CSV.
# Converted JS14283.mat to CSV.
# Converted JS34153.mat to CSV.
# Converted JS04090.mat to CSV.
# Converted JS27649.mat to CSV.
# Converted JS30335.mat to CSV.
# Converted JS07599.mat to CSV.
# Converted JS38769.mat to CSV.
# Converted JS36744.mat to CSV.
# Converted JS08872.mat to CSV.
# Converted JS27891.mat to CSV.
# Converted JS21238.mat to CSV.
# Converted JS39477.mat to CSV.
# Converted JS16494.mat to CSV.
# Converted JS26557.mat to CSV.
# Converted JS17952.mat to CSV.
# Converted JS29664.mat to CSV.
# Converted JS06687.mat to CSV.
# Converted JS26231.mat to CSV.
# Converted JS29102.mat to CSV.
# Converted JS20898.mat to CSV.
# Converted JS36022.mat to CSV.
# Converted JS39311.mat to CSV.
# Converted JS00590.mat to CSV.
# Converted JS20640.mat to CSV.
# Converted JS31995.mat to CSV.
# Converted JS01856.mat to CSV.
# Converted JS10783.mat to CSV.
# Converted JS30453.mat to CSV.
# Converted JS15823.mat to CSV.
# Converted JS03099.mat to CSV.
# Converted JS22057.mat to CSV.
# Converted JS02387.mat to CSV.
# Converted JS32244.mat to CSV.
# Converted JS25738.mat to CSV.
# Converted JS12194.mat to CSV.
# Converted JS15837.mat to CSV.
# Converted JS02393.mat to CSV.
# Converted JS32250.mat to CSV.
# Converted JS12180.mat to CSV.
# Converted JS26225.mat to CSV.
# Converted JS11489.mat to CSV.
# Converted JS31759.mat to CSV.
# Converted JS29116.mat to CSV.
# Converted JS36036.mat to CSV.
# Converted JS39305.mat to CSV.
# Converted JS37328.mat to CSV.
# Converted JS31981.mat to CSV.
# Converted JS20654.mat to CSV.
# Converted JS10797.mat to CSV.
# Converted JS01842.mat to CSV.
# Converted JS28208.mat to CSV.
# Converted JS30447.mat to CSV.
# Converted JS36988.mat to CSV.
# Converted JS30321.mat to CSV.
# Converted JS27885.mat to CSV.
# Converted JS08866.mat to CSV.
# Converted JS36750.mat to CSV.
# Converted JS16480.mat to CSV.
# Converted JS39463.mat to CSV.
# Converted JS26543.mat to CSV.
# Converted JS06693.mat to CSV.
# Converted JS29670.mat to CSV.
# Converted JS17946.mat to CSV.
# Converted JS32536.mat to CSV.
# Converted JS03933.mat to CSV.
# Converted JS22725.mat to CSV.
# Converted JS15189.mat to CSV.
# Converted JS35259.mat to CSV.
# Converted JS14297.mat to CSV.
# Converted JS34147.mat to CSV.
# Converted JS33628.mat to CSV.
# Converted JS04084.mat to CSV.
# Converted JS30309.mat to CSV.
# Converted JS28546.mat to CSV.
# Converted JS27675.mat to CSV.
# Converted JS08696.mat to CSV.
# Converted JS19943.mat to CSV.
# Converted JS06863.mat to CSV.
# Converted JS29880.mat to CSV.
# Converted JS38755.mat to CSV.
# Converted JS40836.mat to CSV.
# Converted JS37466.mat to CSV.
# Converted JS18485.mat to CSV.
# Converted JS21204.mat to CSV.
# Converted JS36778.mat to CSV.
# Converted JS29658.mat to CSV.
# Converted JS31017.mat to CSV.
# Converted JS09588.mat to CSV.
# Converted JS25062.mat to CSV.
# Converted JS44488.mat to CSV.
# Converted JS35271.mat to CSV.
# Converted JS12816.mat to CSV.
# Converted JS33600.mat to CSV.
# Converted JS33166.mat to CSV.
# Converted JS35517.mat to CSV.
# Converted JS04912.mat to CSV.
# Converted JS42947.mat to CSV.
# Converted JS25704.mat to CSV.
# Converted JS43481.mat to CSV.
# Converted JS32278.mat to CSV.
# Converted JS31771.mat to CSV.
# Converted JS40188.mat to CSV.
# Converted JS21562.mat to CSV.
# Converted JS10967.mat to CSV.
# Converted JS38033.mat to CSV.
# Converted JS37300.mat to CSV.
# Converted JS41296.mat to CSV.
# Converted JS28220.mat to CSV.
# Converted JS27113.mat to CSV.
# Converted JS31765.mat to CSV.
# Converted JS26219.mat to CSV.
# Converted JS39339.mat to CSV.
# Converted JS21576.mat to CSV.
# Converted JS10973.mat to CSV.
# Converted JS20668.mat to CSV.
# Converted JS38027.mat to CSV.
# Converted JS37314.mat to CSV.
# Converted JS28234.mat to CSV.
# Converted JS41282.mat to CSV.
# Converted JS27107.mat to CSV.
# Converted JS33172.mat to CSV.
# Converted JS23361.mat to CSV.
# Converted JS35503.mat to CSV.
# Converted JS42953.mat to CSV.
# Converted JS04906.mat to CSV.
# Converted JS25710.mat to CSV.
# Converted JS43495.mat to CSV.
# Converted JS25076.mat to CSV.
# Converted JS35265.mat to CSV.
# Converted JS22719.mat to CSV.
# Converted JS12802.mat to CSV.
# Converted JS33614.mat to CSV.
# Converted JS28552.mat to CSV.
# Converted JS19957.mat to CSV.
# Converted JS08682.mat to CSV.
# Converted JS27661.mat to CSV.
# Converted JS40822.mat to CSV.
# Converted JS38741.mat to CSV.
# Converted JS29894.mat to CSV.
# Converted JS06877.mat to CSV.
# Converted JS18491.mat to CSV.
# Converted JS37472.mat to CSV.
# Converted JS21210.mat to CSV.
# Converted JS31003.mat to CSV.
# Converted JS38999.mat to CSV.
# Converted JS36787.mat to CSV.
# Converted JS19764.mat to CSV.
# Converted JS27852.mat to CSV.
# Converted JS16457.mat to CSV.
# Converted JS26594.mat to CSV.
# Converted JS09577.mat to CSV.
# Converted JS11338.mat to CSV.
# Converted JS40611.mat to CSV.
# Converted JS17991.mat to CSV.
# Converted JS38972.mat to CSV.
# Converted JS06644.mat to CSV.
# Converted JS10026.mat to CSV.
# Converted JS08669.mat to CSV.
# Converted JS37499.mat to CSV.
# Converted JS00235.mat to CSV.
# Converted JS17749.mat to CSV.
# Converted JS14240.mat to CSV.
# Converted JS34190.mat to CSV.
# Converted JS42006.mat to CSV.
# Converted JS04053.mat to CSV.
# Converted JS43318.mat to CSV.
# Converted JS12631.mat to CSV.
# Converted JS33827.mat to CSV.
# Converted JS44477.mat to CSV.
# Converted JS22094.mat to CSV.
# Converted JS15638.mat to CSV.
# Converted JS44311.mat to CSV.
# Converted JS02344.mat to CSV.
# Converted JS32287.mat to CSV.
# Converted JS12157.mat to CSV.
# Converted JS33199.mat to CSV.
# Converted JS42760.mat to CSV.
# Converted JS04735.mat to CSV.
# Converted JS13249.mat to CSV.
# Converted JS14526.mat to CSV.
# Converted JS25923.mat to CSV.
# Converted JS00553.mat to CSV.
# Converted JS31956.mat to CSV.
# Converted JS01895.mat to CSV.
# Converted JS10740.mat to CSV.
# Converted JS41269.mat to CSV.
# Converted JS30490.mat to CSV.
# Converted JS09211.mat to CSV.
# Converted JS40177.mat to CSV.
# Converted JS06122.mat to CSV.
# Converted JS10998.mat to CSV.
# Converted JS19002.mat to CSV.
# Converted JS16331.mat to CSV.
# Converted JS00547.mat to CSV.
# Converted JS18308.mat to CSV.
# Converted JS31942.mat to CSV.
# Converted JS20697.mat to CSV.
# Converted JS10754.mat to CSV.
# Converted JS01881.mat to CSV.
# Converted JS30484.mat to CSV.
# Converted JS07228.mat to CSV.
# Converted JS09205.mat to CSV.
# Converted JS06136.mat to CSV.
# Converted JS40163.mat to CSV.
# Converted JS19016.mat to CSV.
# Converted JS01659.mat to CSV.
# Converted JS21589.mat to CSV.
# Converted JS16325.mat to CSV.
# Converted JS22080.mat to CSV.
# Converted JS02350.mat to CSV.
# Converted JS44305.mat to CSV.
# Converted JS32293.mat to CSV.
# Converted JS12143.mat to CSV.
# Converted JS04721.mat to CSV.
# Converted JS42774.mat to CSV.
# Converted JS14532.mat to CSV.
# Converted JS25937.mat to CSV.
# Converted JS14254.mat to CSV.
# Converted JS34184.mat to CSV.
# Converted JS03728.mat to CSV.
# Converted JS04047.mat to CSV.
# Converted JS42012.mat to CSV.
# Converted JS05359.mat to CSV.
# Converted JS25089.mat to CSV.
# Converted JS12625.mat to CSV.
# Converted JS33833.mat to CSV.
# Converted JS44463.mat to CSV.
# Converted JS27846.mat to CSV.
# Converted JS19770.mat to CSV.
# Converted JS36793.mat to CSV.
# Converted JS16443.mat to CSV.
# Converted JS09563.mat to CSV.
# Converted JS26580.mat to CSV.
# Converted JS06650.mat to CSV.
# Converted JS38966.mat to CSV.
# Converted JS17985.mat to CSV.
# Converted JS40605.mat to CSV.
# Converted JS10032.mat to CSV.
# Converted JS00221.mat to CSV.
# Converted JS06888.mat to CSV.
# Converted JS03700.mat to CSV.
# Converted JS13513.mat to CSV.
# Converted JS22916.mat to CSV.
# Converted JS05371.mat to CSV.
# Converted JS43324.mat to CSV.
# Converted JS15162.mat to CSV.
# Converted JS39488.mat to CSV.
# Converted JS01117.mat to CSV.
# Converted JS19758.mat to CSV.
# Converted JS06678.mat to CSV.
# Converted JS11304.mat to CSV.
# Converted JS28585.mat to CSV.
# Converted JS41533.mat to CSV.
# Converted JS08655.mat to CSV.
# Converted JS19980.mat to CSV.
# Converted JS36963.mat to CSV.
# Converted JS29843.mat to CSV.
# Converted JS38796.mat to CSV.
# Converted JS17775.mat to CSV.
# Converted JS18446.mat to CSV.
# Converted JS00209.mat to CSV.
# Converted JS17013.mat to CSV.
# Converted JS18320.mat to CSV.
# Converted JS07200.mat to CSV.
# Converted JS41255.mat to CSV.
# Converted JS08133.mat to CSV.
# Converted JS20867.mat to CSV.
# Converted JS11462.mat to CSV.
# Converted JS01671.mat to CSV.
# Converted JS02378.mat to CSV.
# Converted JS42984.mat to CSV.
# Converted JS15604.mat to CSV.
# Converted JS34812.mat to CSV.
# Converted JS05417.mat to CSV.
# Converted JS43442.mat to CSV.
# Converted JS13275.mat to CSV.
# Converted JS04709.mat to CSV.
# Converted JS03066.mat to CSV.
# Converted JS45033.mat to CSV.
# Converted JS44339.mat to CSV.
# Converted JS15610.mat to CSV.
# Converted JS42990.mat to CSV.
# Converted JS34806.mat to CSV.
# Converted JS43456.mat to CSV.
# Converted JS05403.mat to CSV.
# Converted JS13261.mat to CSV.
# Converted JS42748.mat to CSV.
# Converted JS45027.mat to CSV.
# Converted JS03072.mat to CSV.
# Converted JS17007.mat to CSV.
# Converted JS18334.mat to CSV.
# Converted JS41241.mat to CSV.
# Converted JS07214.mat to CSV.
# Converted JS08127.mat to CSV.
# Converted JS10768.mat to CSV.
# Converted JS20873.mat to CSV.
# Converted JS11476.mat to CSV.
# Converted JS09239.mat to CSV.
# Converted JS16319.mat to CSV.
# Converted JS01665.mat to CSV.
# Converted JS08899.mat to CSV.
# Converted JS01103.mat to CSV.
# Converted JS11310.mat to CSV.
# Converted JS41527.mat to CSV.
# Converted JS07572.mat to CSV.
# Converted JS28591.mat to CSV.
# Converted JS36977.mat to CSV.
# Converted JS19994.mat to CSV.
# Converted JS08641.mat to CSV.
# Converted JS17761.mat to CSV.
# Converted JS38782.mat to CSV.
# Converted JS29857.mat to CSV.
# Converted JS18452.mat to CSV.
# Converted JS03714.mat to CSV.
# Converted JS14268.mat to CSV.
# Converted JS13507.mat to CSV.
# Converted JS22902.mat to CSV.
# Converted JS12619.mat to CSV.
# Converted JS43330.mat to CSV.
# Converted JS05365.mat to CSV.
# Converted JS15176.mat to CSV.
# Converted JS01664.mat to CSV.
# Converted JS16318.mat to CSV.
# Converted JS11477.mat to CSV.
# Converted JS09238.mat to CSV.
# Converted JS20872.mat to CSV.
# Converted JS08126.mat to CSV.
# Converted JS10769.mat to CSV.
# Converted JS41240.mat to CSV.
# Converted JS07215.mat to CSV.
# Converted JS18335.mat to CSV.
# Converted JS17006.mat to CSV.
# Converted JS45026.mat to CSV.
# Converted JS03073.mat to CSV.
# Converted JS42749.mat to CSV.
# Converted JS13260.mat to CSV.
# Converted JS43457.mat to CSV.
# Converted JS05402.mat to CSV.
# Converted JS34807.mat to CSV.
# Converted JS15611.mat to CSV.
# Converted JS42991.mat to CSV.
# Converted JS44338.mat to CSV.
# Converted JS15177.mat to CSV.
# Converted JS43331.mat to CSV.
# Converted JS05364.mat to CSV.
# Converted JS12618.mat to CSV.
# Converted JS22903.mat to CSV.
# Converted JS13506.mat to CSV.
# Converted JS14269.mat to CSV.
# Converted JS03715.mat to CSV.
# Converted JS18453.mat to CSV.
# Converted JS29856.mat to CSV.
# Converted JS38783.mat to CSV.
# Converted JS17760.mat to CSV.
# Converted JS08640.mat to CSV.
# Converted JS19995.mat to CSV.
# Converted JS36976.mat to CSV.
# Converted JS41526.mat to CSV.
# Converted JS28590.mat to CSV.
# Converted JS07573.mat to CSV.
# Converted JS11311.mat to CSV.
# Converted JS40638.mat to CSV.
# Converted JS08898.mat to CSV.
# Converted JS01102.mat to CSV.
# Converted JS18447.mat to CSV.
# Converted JS00208.mat to CSV.
# Converted JS17774.mat to CSV.
# Converted JS38797.mat to CSV.
# Converted JS29842.mat to CSV.
# Converted JS36962.mat to CSV.
# Converted JS19981.mat to CSV.
# Converted JS08654.mat to CSV.
# Converted JS07567.mat to CSV.
# Converted JS28584.mat to CSV.
# Converted JS41532.mat to CSV.
# Converted JS11305.mat to CSV.
# Converted JS06679.mat to CSV.
# Converted JS01116.mat to CSV.
# Converted JS19759.mat to CSV.
# Converted JS39489.mat to CSV.
# Converted JS15163.mat to CSV.
# Converted JS05370.mat to CSV.
# Converted JS43325.mat to CSV.
# Converted JS22917.mat to CSV.
# Converted JS13512.mat to CSV.
# Converted JS03701.mat to CSV.
# Converted JS03067.mat to CSV.
# Converted JS45032.mat to CSV.
# Converted JS04708.mat to CSV.
# Converted JS13274.mat to CSV.
# Converted JS05416.mat to CSV.
# Converted JS43443.mat to CSV.
# Converted JS34813.mat to CSV.
# Converted JS42985.mat to CSV.
# Converted JS15605.mat to CSV.
# Converted JS02379.mat to CSV.
# Converted JS01670.mat to CSV.
# Converted JS11463.mat to CSV.
# Converted JS20866.mat to CSV.
# Converted JS08132.mat to CSV.
# Converted JS07201.mat to CSV.
# Converted JS41254.mat to CSV.
# Converted JS18321.mat to CSV.
# Converted JS17012.mat to CSV.
# Converted JS25936.mat to CSV.
# Converted JS14533.mat to CSV.
# Converted JS04720.mat to CSV.
# Converted JS42775.mat to CSV.
# Converted JS12142.mat to CSV.
# Converted JS32292.mat to CSV.
# Converted JS02351.mat to CSV.
# Converted JS44304.mat to CSV.
# Converted JS22081.mat to CSV.
# Converted JS21588.mat to CSV.
# Converted JS16324.mat to CSV.
# Converted JS19017.mat to CSV.
# Converted JS01658.mat to CSV.
# Converted JS06137.mat to CSV.
# Converted JS40162.mat to CSV.
# Converted JS09204.mat to CSV.
# Converted JS30485.mat to CSV.
# Converted JS07229.mat to CSV.
# Converted JS01880.mat to CSV.
# Converted JS10755.mat to CSV.
# Converted JS20696.mat to CSV.
# Converted JS31943.mat to CSV.
# Converted JS00546.mat to CSV.
# Converted JS18309.mat to CSV.
# Converted JS06889.mat to CSV.
# Converted JS00220.mat to CSV.
# Converted JS10033.mat to CSV.
# Converted JS17984.mat to CSV.
# Converted JS38967.mat to CSV.
# Converted JS06651.mat to CSV.
# Converted JS40604.mat to CSV.
# Converted JS26581.mat to CSV.
# Converted JS09562.mat to CSV.
# Converted JS16442.mat to CSV.
# Converted JS36792.mat to CSV.
# Converted JS19771.mat to CSV.
# Converted JS27847.mat to CSV.
# Converted JS02437.mat to CSV.
# Converted JS44462.mat to CSV.
# Converted JS33832.mat to CSV.
# Converted JS25088.mat to CSV.
# Converted JS12624.mat to CSV.
# Converted JS05358.mat to CSV.
# Converted JS04046.mat to CSV.
# Converted JS42013.mat to CSV.
# Converted JS34185.mat to CSV.
# Converted JS03729.mat to CSV.
# Converted JS14255.mat to CSV.
# Converted JS44476.mat to CSV.
# Converted JS33826.mat to CSV.
# Converted JS12630.mat to CSV.
# Converted JS43319.mat to CSV.
# Converted JS42007.mat to CSV.
# Converted JS04052.mat to CSV.
# Converted JS34191.mat to CSV.
# Converted JS14241.mat to CSV.
# Converted JS37498.mat to CSV.
# Converted JS00234.mat to CSV.
# Converted JS10027.mat to CSV.
# Converted JS08668.mat to CSV.
# Converted JS40610.mat to CSV.
# Converted JS06645.mat to CSV.
# Converted JS38973.mat to CSV.
# Converted JS17990.mat to CSV.
# Converted JS09576.mat to CSV.
# Converted JS26595.mat to CSV.
# Converted JS11339.mat to CSV.
# Converted JS16456.mat to CSV.
# Converted JS27853.mat to CSV.
# Converted JS19765.mat to CSV.
# Converted JS36786.mat to CSV.
# Converted JS16330.mat to CSV.
# Converted JS10999.mat to CSV.
# Converted JS19003.mat to CSV.
# Converted JS40176.mat to CSV.
# Converted JS06123.mat to CSV.
# Converted JS09210.mat to CSV.
# Converted JS41268.mat to CSV.
# Converted JS10741.mat to CSV.
# Converted JS01894.mat to CSV.
# Converted JS31957.mat to CSV.
# Converted JS20682.mat to CSV.
# Converted JS00552.mat to CSV.
# Converted JS25922.mat to CSV.
# Converted JS14527.mat to CSV.
# Converted JS13248.mat to CSV.
# Converted JS42761.mat to CSV.
# Converted JS33198.mat to CSV.
# Converted JS04734.mat to CSV.
# Converted JS12156.mat to CSV.
# Converted JS32286.mat to CSV.
# Converted JS44310.mat to CSV.
# Converted JS02345.mat to CSV.
# Converted JS22095.mat to CSV.
# Converted JS15639.mat to CSV.
# Converted JS43494.mat to CSV.
# Converted JS25711.mat to CSV.
# Converted JS42952.mat to CSV.
# Converted JS04907.mat to CSV.
# Converted JS35502.mat to CSV.
# Converted JS33173.mat to CSV.
# Converted JS27106.mat to CSV.
# Converted JS28235.mat to CSV.
# Converted JS41283.mat to CSV.
# Converted JS37315.mat to CSV.
# Converted JS20669.mat to CSV.
# Converted JS38026.mat to CSV.
# Converted JS10972.mat to CSV.
# Converted JS39338.mat to CSV.
# Converted JS21577.mat to CSV.
# Converted JS26218.mat to CSV.
# Converted JS31764.mat to CSV.
# Converted JS31002.mat to CSV.
# Converted JS38998.mat to CSV.
# Converted JS21211.mat to CSV.
# Converted JS37473.mat to CSV.
# Converted JS18490.mat to CSV.
# Converted JS40823.mat to CSV.
# Converted JS29895.mat to CSV.
# Converted JS38740.mat to CSV.
# Converted JS27660.mat to CSV.
# Converted JS08683.mat to CSV.
# Converted JS19956.mat to CSV.
# Converted JS28553.mat to CSV.
# Converted JS33615.mat to CSV.
# Converted JS12803.mat to CSV.
# Converted JS22718.mat to CSV.
# Converted JS35264.mat to CSV.
# Converted JS25077.mat to CSV.
# Converted JS33601.mat to CSV.
# Converted JS12817.mat to CSV.
# Converted JS35270.mat to CSV.
# Converted JS44489.mat to CSV.
# Converted JS25063.mat to CSV.
# Converted JS09589.mat to CSV.
# Converted JS29659.mat to CSV.
# Converted JS31016.mat to CSV.
# Converted JS36779.mat to CSV.
# Converted JS21205.mat to CSV.
# Converted JS18484.mat to CSV.
# Converted JS37467.mat to CSV.
# Converted JS38754.mat to CSV.
# Converted JS29881.mat to CSV.
# Converted JS06862.mat to CSV.
# Converted JS40837.mat to CSV.
# Converted JS19942.mat to CSV.
# Converted JS08697.mat to CSV.
# Converted JS27674.mat to CSV.
# Converted JS30308.mat to CSV.
# Converted JS28547.mat to CSV.
# Converted JS27112.mat to CSV.
# Converted JS41297.mat to CSV.
# Converted JS28221.mat to CSV.
# Converted JS37301.mat to CSV.
# Converted JS38032.mat to CSV.
# Converted JS10966.mat to CSV.
# Converted JS21563.mat to CSV.
# Converted JS40189.mat to CSV.
# Converted JS31770.mat to CSV.
# Converted JS32279.mat to CSV.
# Converted JS43480.mat to CSV.
# Converted JS25705.mat to CSV.
# Converted JS42946.mat to CSV.
# Converted JS35516.mat to CSV.
# Converted JS33167.mat to CSV.
# Converted JS28209.mat to CSV.
# Converted JS30446.mat to CSV.
# Converted JS01843.mat to CSV.
# Converted JS10796.mat to CSV.
# Converted JS20655.mat to CSV.
# Converted JS31980.mat to CSV.
# Converted JS37329.mat to CSV.
# Converted JS00585.mat to CSV.
# Converted JS39304.mat to CSV.
# Converted JS36037.mat to CSV.
# Converted JS31758.mat to CSV.
# Converted JS29117.mat to CSV.
# Converted JS26224.mat to CSV.
# Converted JS11488.mat to CSV.
# Converted JS12181.mat to CSV.
# Converted JS32251.mat to CSV.
# Converted JS02392.mat to CSV.
# Converted JS22042.mat to CSV.
# Converted JS15836.mat to CSV.
# Converted JS33629.mat to CSV.
# Converted JS04085.mat to CSV.
# Converted JS34146.mat to CSV.
# Converted JS14296.mat to CSV.
# Converted JS35258.mat to CSV.
# Converted JS22724.mat to CSV.
# Converted JS15188.mat to CSV.
# Converted JS03932.mat to CSV.
# Converted JS32537.mat to CSV.
# Converted JS17947.mat to CSV.
# Converted JS29671.mat to CSV.
# Converted JS06692.mat to CSV.
# Converted JS26542.mat to CSV.
# Converted JS39462.mat to CSV.
# Converted JS16481.mat to CSV.
# Converted JS36751.mat to CSV.
# Converted JS08867.mat to CSV.
# Converted JS27884.mat to CSV.
# Converted JS30320.mat to CSV.
# Converted JS36989.mat to CSV.
# Converted JS06686.mat to CSV.
# Converted JS29665.mat to CSV.
# ...
# Converted JS18701.mat to CSV.
# Converted JS21180.mat to CSV.
# Converted JS01250.mat to CSV.
# Converted JS31393.mat to CSV.
# Converted JS11043.mat to CSV.
# Converted JS39903.mat to CSV.
# Converted JS41660.mat to CSV.
# Converted JS30099.mat to CSV.
# Converted JS10349.mat to CSV.
# Converted JS08506.mat to CSV.
# Converted JS17426.mat to CSV.
# Converted JS18715.mat to CSV.
# Converted JS26823.mat to CSV.
# Converted JS16738.mat to CSV.
# Converted JS21194.mat to CSV.
# Converted JS01244.mat to CSV.
# Converted JS31387.mat to CSV.
# Converted JS09618.mat to CSV.
# Converted JS11057.mat to CSV.
# Converted JS05022.mat to CSV.
# Converted JS43077.mat to CSV.
# Converted JS44718.mat to CSV.
# Converted JS13898.mat to CSV.
# Converted JS15231.mat to CSV.
# Converted JS03453.mat to CSV.
# Converted JS32856.mat to CSV.
# Converted JS23783.mat to CSV.
# Converted JS13640.mat to CSV.
# Converted JS02995.mat to CSV.
# Converted JS33590.mat to CSV.
# Converted JS42369.mat to CSV.
# Converted JS13126.mat to CSV.
# Converted JS03335.mat to CSV.
# Converted JS14649.mat to CSV.
# Converted JS24952.mat to CSV.
# Converted JS35687.mat to CSV.
# Converted JS15557.mat to CSV.
# Converted JS12238.mat to CSV.
# Converted JS25494.mat to CSV.
# Converted JS05744.mat to CSV.
# Converted JS14891.mat to CSV.
# Converted JS43711.mat to CSV.
# Converted JS40218.mat to CSV.
# Converted JS11731.mat to CSV.
# Converted JS30927.mat to CSV.
# Converted JS01522.mat to CSV.
# Converted JS17340.mat to CSV.
# Converted JS37090.mat to CSV.
# Converted JS18073.mat to CSV.
# Converted JS07153.mat to CSV.
# Converted JS41106.mat to CSV.
# Converted JS27283.mat to CSV.
# Converted JS08260.mat to CSV.
# Converted JS18098.mat to CSV.
# Converted JS11902.mat to CSV.
# Converted JS20507.mat to CSV.
# Converted JS38348.mat to CSV.
# Converted JS27268.mat to CSV.
# Converted JS30714.mat to CSV.
# Converted JS09195.mat to CSV.
# Converted JS26176.mat to CSV.
# Converted JS29245.mat to CSV.
# Converted JS36365.mat to CSV.
# Converted JS39056.mat to CSV.
# Converted JS21619.mat to CSV.
# Converted JS22310.mat to CSV.
# Converted JS44095.mat to CSV.
# Converted JS32103.mat to CSV.
# Converted JS24761.mat to CSV.
# Converted JS05977.mat to CSV.
# Converted JS43922.mat to CSV.
# Converted JS23768.mat to CSV.
# Converted JS34214.mat to CSV.
# Converted JS42382.mat to CSV.
# Converted JS24007.mat to CSV.
# Converted JS32665.mat to CSV.
# Converted JS25319.mat to CSV.
# Converted JS22476.mat to CSV.
# Converted JS13873.mat to CSV.
# Converted JS36403.mat to CSV.
# Converted JS39730.mat to CSV.
# Converted JS07806.mat to CSV.
# Converted JS41853.mat to CSV.
# Converted JS18926.mat to CSV.
# Converted JS26610.mat to CSV.
# Converted JS40595.mat to CSV.
# Converted JS29523.mat to CSV.
# Converted JS30072.mat to CSV.
# Converted JS20261.mat to CSV.
# Converted JS36417.mat to CSV.
# Converted JS41847.mat to CSV.
# Converted JS07812.mat to CSV.
# Converted JS39724.mat to CSV.
# Converted JS26604.mat to CSV.
# Converted JS18932.mat to CSV.
# Converted JS29537.mat to CSV.
# Converted JS31378.mat to CSV.
# Converted JS40581.mat to CSV.
# Converted JS30066.mat to CSV.
# Converted JS28629.mat to CSV.
# Converted JS37709.mat to CSV.
# Converted JS20275.mat to CSV.
# Converted JS34200.mat to CSV.
# Converted JS42396.mat to CSV.
# Converted JS24013.mat to CSV.
# Converted JS43088.mat to CSV.
# Converted JS32671.mat to CSV.
# Converted JS13867.mat to CSV.
# Converted JS22304.mat to CSV.
# Converted JS44081.mat to CSV.
# Converted JS35678.mat to CSV.
# Converted JS32117.mat to CSV.
# Converted JS33209.mat to CSV.
# Converted JS24775.mat to CSV.
# Converted JS43936.mat to CSV.
# Converted JS05963.mat to CSV.
# Converted JS11916.mat to CSV.
# Converted JS20513.mat to CSV.
# Converted JS30700.mat to CSV.
# Converted JS26162.mat to CSV.
# Converted JS09181.mat to CSV.
# Converted JS29251.mat to CSV.
# Converted JS36371.mat to CSV.
# Converted JS19392.mat to CSV.
# Converted JS39042.mat to CSV.
# Converted JS35650.mat to CSV.
# Converted JS24985.mat to CSV.
# Converted JS15580.mat to CSV.
# Converted JS25443.mat to CSV.
# Converted JS14846.mat to CSV.
# Converted JS05793.mat to CSV.
# Converted JS35888.mat to CSV.
# Converted JS33221.mat to CSV.
# Converted JS23032.mat to CSV.
# Converted JS17397.mat to CSV.
# Converted JS38374.mat to CSV.
# Converted JS37047.mat to CSV.
# Converted JS07184.mat to CSV.
# Converted JS28167.mat to CSV.
# Converted JS30728.mat to CSV.
# Converted JS27254.mat to CSV.
# Converted JS31436.mat to CSV.
# Converted JS29279.mat to CSV.
# Converted JS00833.mat to CSV.
# Converted JS16089.mat to CSV.
# Converted JS21625.mat to CSV.
# Converted JS36359.mat to CSV.
# Converted JS21143.mat to CSV.
# Converted JS01293.mat to CSV.
# Converted JS31350.mat to CSV.
# Converted JS11080.mat to CSV.
# Converted JS28601.mat to CSV.
# Converted JS16937.mat to CSV.
# Converted JS27532.mat to CSV.
# Converted JS38412.mat to CSV.
# Converted JS09817.mat to CSV.
# Converted JS37721.mat to CSV.
# Converted JS03484.mat to CSV.
# Converted JS34228.mat to CSV.
# Converted JS23754.mat to CSV.
# Converted JS32881.mat to CSV.
# Converted JS44917.mat to CSV.
# Converted JS02942.mat to CSV.
# Converted JS13697.mat to CSV.
# Converted JS33547.mat to CSV.
# Converted JS12589.mat to CSV.
# Converted JS25325.mat to CSV.
# Converted JS32659.mat to CSV.
# Converted JS35136.mat to CSV.
# Converted JS03490.mat to CSV.
# Converted JS32895.mat to CSV.
# Converted JS23740.mat to CSV.
# Converted JS13683.mat to CSV.
# Converted JS02956.mat to CSV.
# Converted JS44903.mat to CSV.
# Converted JS33553.mat to CSV.
# Converted JS25331.mat to CSV.
# Converted JS23998.mat to CSV.
# Converted JS35122.mat to CSV.
# Converted JS21157.mat to CSV.
# Converted JS39718.mat to CSV.
# Converted JS01287.mat to CSV.
# Converted JS31344.mat to CSV.
# Converted JS11094.mat to CSV.
# Converted JS26638.mat to CSV.
# Converted JS16923.mat to CSV.
# Converted JS28615.mat to CSV.
# Converted JS27526.mat to CSV.
# Converted JS38406.mat to CSV.
# Converted JS20249.mat to CSV.
# Converted JS00199.mat to CSV.
# Converted JS37735.mat to CSV.
# Converted JS09803.mat to CSV.
# Converted JS38360.mat to CSV.
# Converted JS17383.mat to CSV.
# Converted JS37053.mat to CSV.
# Converted JS28173.mat to CSV.
# Converted JS07190.mat to CSV.
# Converted JS27240.mat to CSV.
# Converted JS31422.mat to CSV.
# Converted JS00827.mat to CSV.
# Converted JS21631.mat to CSV.
# Converted JS24991.mat to CSV.
# Converted JS35644.mat to CSV.
# Converted JS15594.mat to CSV.
# Converted JS22338.mat to CSV.
# Converted JS25457.mat to CSV.
# Converted JS05787.mat to CSV.
# Converted JS14852.mat to CSV.
# Converted JS24749.mat to CSV.
# Converted JS04499.mat to CSV.
# Converted JS33235.mat to CSV.
# Converted JS23026.mat to CSV.
# Converted JS42143.mat to CSV.
# Converted JS04116.mat to CSV.
# Converted JS03679.mat to CSV.
# Converted JS14305.mat to CSV.
# Converted JS44532.mat to CSV.
# Converted JS02567.mat to CSV.
# Converted JS33962.mat to CSV.
# Converted JS12774.mat to CSV.
# Converted JS05208.mat to CSV.
# Converted JS40754.mat to CSV.
# Converted JS06701.mat to CSV.
# Converted JS38837.mat to CSV.
# Converted JS09432.mat to CSV.
# Converted JS16512.mat to CSV.
# Converted JS27917.mat to CSV.
# Converted JS19621.mat to CSV.
# Converted JS00370.mat to CSV.
# Converted JS10163.mat to CSV.
# Converted JS07379.mat to CSV.
# Converted JS10605.mat to CSV.
# Converted JS31813.mat to CSV.
# Converted JS38189.mat to CSV.
# Converted JS18259.mat to CSV.
# Converted JS16274.mat to CSV.
# Converted JS39297.mat to CSV.
# Converted JS01708.mat to CSV.
# Converted JS19147.mat to CSV.
# Converted JS40032.mat to CSV.
# Converted JS06067.mat to CSV.
# Converted JS29084.mat to CSV.
# Converted JS09354.mat to CSV.
# Converted JS12012.mat to CSV.
# Converted JS44254.mat to CSV.
# Converted JS02201.mat to CSV.
# Converted JS25866.mat to CSV.
# Converted JS14463.mat to CSV.
# Converted JS42625.mat to CSV.
# Converted JS04670.mat to CSV.
# Converted JS12006.mat to CSV.
# Converted JS02215.mat to CSV.
# Converted JS44240.mat to CSV.
# Converted JS15769.mat to CSV.
# Converted JS25872.mat to CSV.
# Converted JS14477.mat to CSV.
# Converted JS13318.mat to CSV.
# Converted JS04664.mat to CSV.
# Converted JS42631.mat to CSV.
# Converted JS41338.mat to CSV.
# Converted JS10611.mat to CSV.
# Converted JS31807.mat to CSV.
# Converted JS00402.mat to CSV.
# Converted JS39283.mat to CSV.
# Converted JS16260.mat to CSV.
# Converted JS19153.mat to CSV.
# Converted JS29090.mat to CSV.
# Converted JS06073.mat to CSV.
# Converted JS40026.mat to CSV.
# Converted JS09340.mat to CSV.
# Converted JS38823.mat to CSV.
# Converted JS06715.mat to CSV.
# Converted JS40740.mat to CSV.
# Converted JS11269.mat to CSV.
# Converted JS09426.mat to CSV.
# Converted JS16506.mat to CSV.
# Converted JS19635.mat to CSV.
# Converted JS27903.mat to CSV.
# Converted JS17618.mat to CSV.
# Converted JS40998.mat to CSV.
# Converted JS00364.mat to CSV.
# Converted JS08738.mat to CSV.
# Converted JS10177.mat to CSV.
# Converted JS04102.mat to CSV.
# Converted JS42157.mat to CSV.
# Converted JS14311.mat to CSV.
# Converted JS02573.mat to CSV.
# Converted JS44526.mat to CSV.
# Converted JS33976.mat to CSV.
# Converted JS12760.mat to CSV.
# Converted JS43249.mat to CSV.
# Converted JS11241.mat to CSV.
# Converted JS40768.mat to CSV.
# Converted JS01052.mat to CSV.
# Converted JS21382.mat to CSV.
# Converted JS18503.mat to CSV.
# Converted JS17630.mat to CSV.
# Converted JS29906.mat to CSV.
# Converted JS08710.mat to CSV.
# Converted JS07423.mat to CSV.
# Converted JS41476.mat to CSV.
# Converted JS33786.mat to CSV.
# Converted JS22853.mat to CSV.
# Converted JS13456.mat to CSV.
# Converted JS14339.mat to CSV.
# Converted JS23595.mat to CSV.
# Converted JS12990.mat to CSV.
# Converted JS03645.mat to CSV.
# Converted JS15027.mat to CSV.
# Converted JS05234.mat to CSV.
# Converted JS32498.mat to CSV.
# Converted JS43261.mat to CSV.
# Converted JS12748.mat to CSV.
# Converted JS05552.mat to CSV.
# Converted JS43507.mat to CSV.
# Converted JS25682.mat to CSV.
# Converted JS34957.mat to CSV.
# Converted JS04894.mat to CSV.
# Converted JS15741.mat to CSV.
# Converted JS35491.mat to CSV.
# Converted JS44268.mat to CSV.
# Converted JS03123.mat to CSV.
# Converted JS45176.mat to CSV.
# Converted JS42619.mat to CSV.
# Converted JS15999.mat to CSV.
# Converted JS13330.mat to CSV.
# Converted JS10639.mat to CSV.
# Converted JS08076.mat to CSV.
# Converted JS27095.mat to CSV.
# Converted JS07345.mat to CSV.
# Converted JS41310.mat to CSV.
# Converted JS18265.mat to CSV.
# Converted JS37286.mat to CSV.
# Converted JS17156.mat to CSV.
# Converted JS01734.mat to CSV.
# Converted JS36198.mat to CSV.
# Converted JS16248.mat to CSV.
# Converted JS11527.mat to CSV.
# Converted JS27081.mat to CSV.
# Converted JS08062.mat to CSV.
# Converted JS41304.mat to CSV.
# Converted JS07351.mat to CSV.
# Converted JS37292.mat to CSV.
# Converted JS18271.mat to CSV.
# Converted JS17142.mat to CSV.
# Converted JS01720.mat to CSV.
# Converted JS11533.mat to CSV.
# Converted JS43513.mat to CSV.
# Converted JS05546.mat to CSV.
# Converted JS34943.mat to CSV.
# Converted JS25696.mat to CSV.
# Converted JS15755.mat to CSV.
# Converted JS04880.mat to CSV.
# Converted JS02229.mat to CSV.
# Converted JS35485.mat to CSV.
# Converted JS45162.mat to CSV.
# Converted JS03137.mat to CSV.
# Converted JS04658.mat to CSV.
# Converted JS13324.mat to CSV.
# Converted JS22847.mat to CSV.
# Converted JS33792.mat to CSV.
# Converted JS13442.mat to CSV.
# Converted JS23581.mat to CSV.
# Converted JS12984.mat to CSV.
# Converted JS15033.mat to CSV.
# Converted JS43275.mat to CSV.
# Converted JS05220.mat to CSV.
# Converted JS03889.mat to CSV.
# Converted JS11255.mat to CSV.
# Converted JS06729.mat to CSV.
# Converted JS31185.mat to CSV.
# Converted JS19609.mat to CSV.
# Converted JS01046.mat to CSV.
# Converted JS21396.mat to CSV.
# Converted JS00358.mat to CSV.
# Converted JS18517.mat to CSV.
# Converted JS29912.mat to CSV.
# Converted JS17624.mat to CSV.
# Converted JS20088.mat to CSV.
# Converted JS08704.mat to CSV.
# Converted JS36832.mat to CSV.
# Converted JS41462.mat to CSV.
# Converted JS07437.mat to CSV.
# Converted JS20063.mat to CSV.
# Converted JS30270.mat to CSV.
# Converted JS41489.mat to CSV.
# Converted JS29721.mat to CSV.
# Converted JS17817.mat to CSV.
# Converted JS40797.mat to CSV.
# Converted JS26412.mat to CSV.
# Converted JS39532.mat to CSV.
# Converted JS08937.mat to CSV.
# Converted JS36601.mat to CSV.
# Converted JS35308.mat to CSV.
# Converted JS22674.mat to CSV.
# Converted JS03862.mat to CSV.
# Converted JS32467.mat to CSV.
# Converted JS42180.mat to CSV.
# Converted JS33779.mat to CSV.
# Converted JS34016.mat to CSV.
# Converted JS45189.mat to CSV.
# Converted JS15966.mat to CSV.
# Converted JS32301.mat to CSV.
# Converted JS44297.mat to CSV.
# Converted JS22112.mat to CSV.
# Converted JS39254.mat to CSV.
# Converted JS36167.mat to CSV.
# Converted JS29047.mat to CSV.
# Converted JS31608.mat to CSV.
# Converted JS09397.mat to CSV.
# Converted JS26374.mat to CSV.
# Converted JS30516.mat to CSV.
# Converted JS08089.mat to CSV.
# Converted JS01913.mat to CSV.
# Converted JS20705.mat to CSV.
# Converted JS37279.mat to CSV.
# Converted JS39240.mat to CSV.
# Converted JS36173.mat to CSV.
# Converted JS29053.mat to CSV.
# Converted JS26360.mat to CSV.
# Converted JS09383.mat to CSV.
# Converted JS30502.mat to CSV.
# Converted JS01907.mat to CSV.
# Converted JS20711.mat to CSV.
# Converted JS15972.mat to CSV.
# Converted JS25669.mat to CSV.
# Converted JS32315.mat to CSV.
# Converted JS44283.mat to CSV.
# Converted JS22106.mat to CSV.
# Converted JS22660.mat to CSV.
# Converted JS03876.mat to CSV.
# Converted JS32473.mat to CSV.
# Converted JS42194.mat to CSV.
# Converted JS34002.mat to CSV.
# Converted JS20077.mat to CSV.
# Converted JS38638.mat to CSV.
# Converted JS30264.mat to CSV.
# Converted JS27718.mat to CSV.
# Converted JS40783.mat to CSV.
# Converted JS17803.mat to CSV.
# Converted JS29735.mat to CSV.
# Converted JS26406.mat to CSV.
# Converted JS39526.mat to CSV.
# Converted JS21369.mat to CSV.
# Converted JS36615.mat to CSV.
# Converted JS08923.mat to CSV.
# Converted JS22648.mat to CSV.
# Converted JS02598.mat to CSV.
# Converted JS35334.mat to CSV.
# Converted JS25127.mat to CSV.
# Converted JS33745.mat to CSV.
# Converted JS22890.mat to CSV.
# Converted JS13495.mat to CSV.
# Converted JS23556.mat to CSV.
# Converted JS12953.mat to CSV.
# Converted JS03686.mat to CSV.
# Converted JS37523.mat to CSV.
# Converted JS38610.mat to CSV.
# Converted JS06926.mat to CSV.
# Converted JS40973.mat to CSV.
# Converted JS19806.mat to CSV.
# Converted JS27730.mat to CSV.
# Converted JS28403.mat to CSV.
# Converted JS11282.mat to CSV.
# Converted JS31152.mat to CSV.
# Converted JS01091.mat to CSV.
# Converted JS21341.mat to CSV.
# Converted JS10822.mat to CSV.
# Converted JS21427.mat to CSV.
# Converted JS39268.mat to CSV.
# Converted JS26348.mat to CSV.
# Converted JS06098.mat to CSV.
# Converted JS31634.mat to CSV.
# Converted JS27056.mat to CSV.
# Converted JS07386.mat to CSV.
# Converted JS28365.mat to CSV.
# Converted JS37245.mat to CSV.
# Converted JS17195.mat to CSV.
# Converted JS38176.mat to CSV.
# Converted JS20739.mat to CSV.
# Converted JS25899.mat to CSV.
# Converted JS33023.mat to CSV.
# Converted JS05591.mat to CSV.
# Converted JS25641.mat to CSV.
# Converted JS34994.mat to CSV.
# Converted JS04857.mat to CSV.
# Converted JS15782.mat to CSV.
# Converted JS42802.mat to CSV.
# Converted JS35452.mat to CSV.
# Converted JS14488.mat to CSV.
# Converted JS33037.mat to CSV.
# Converted JS05585.mat to CSV.
# Converted JS32329.mat to CSV.
# Converted JS34980.mat to CSV.
# Converted JS25655.mat to CSV.
# Converted JS42816.mat to CSV.
# Converted JS15796.mat to CSV.
# Converted JS04843.mat to CSV.
# Converted JS35446.mat to CSV.
# Converted JS10836.mat to CSV.
# Converted JS21433.mat to CSV.
# Converted JS31620.mat to CSV.
# Converted JS27042.mat to CSV.
# Converted JS28371.mat to CSV.
# Converted JS07392.mat to CSV.
# Converted JS37251.mat to CSV.
# Converted JS38162.mat to CSV.
# Converted JS17181.mat to CSV.
# Converted JS37537.mat to CSV.
# Converted JS40967.mat to CSV.
# Converted JS06932.mat to CSV.
# Converted JS38604.mat to CSV.
# Converted JS10188.mat to CSV.
# Converted JS27724.mat to CSV.
# Converted JS19812.mat to CSV.
# Converted JS28417.mat to CSV.
# Converted JS30258.mat to CSV.
# Converted JS11296.mat to CSV.
# Converted JS31146.mat to CSV.
# Converted JS29709.mat to CSV.
# Converted JS01085.mat to CSV.
# Converted JS36629.mat to CSV.
# Converted JS21355.mat to CSV.
# Converted JS33989.mat to CSV.
# Converted JS35320.mat to CSV.
# Converted JS25133.mat to CSV.
# Converted JS22884.mat to CSV.
# Converted JS33751.mat to CSV.
# Converted JS13481.mat to CSV.
# Converted JS23542.mat to CSV.
# Converted JS03692.mat to CSV.
# Converted JS12947.mat to CSV.

# %%
import os
# Target folder path
target_folder = '../01_Database_ECGSignal_Rhythm'

# Get the count of files in the folder
file_count = len([f for f in os.listdir(target_folder) if os.path.isfile(os.path.join(target_folder, f))])

print(f"Number of files in the 01_Database_PhysioNet_Rhythm folder: {file_count}")
# Out:
# Number of files in the 01_Database_PhysioNet_Rhythm folder: 128406

# %%
import matplotlib.pyplot as plt
import scipy.io
import numpy as np
import pandas as pd

df_raw = pd.read_csv('../01_Database_ECGSignal_Rhythm/JS00005.csv')
df_raw
# Out:
#        I   II  III  aVR  aVL  aVF   V1   V2   V3   V4   V5   V6
# 0      5 -146 -151   73   78 -151 -273 -386 -381 -356 -220 -176
# 1      5 -127 -132   63   68 -132 -229 -332 -342 -317 -190 -161
# 2    -15 -127 -112   73   49 -122 -205 -288 -303 -288 -166 -146
# 3     -5 -127 -122   68   59 -127 -200 -264 -298 -298 -190 -161
# 4     -5 -127 -122   68   59 -127 -181 -244 -278 -278 -181 -151
# ...   ..  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
# 4995 -44 -210 -166  127   59 -190 -156 -361 -337 -249 -195 -122
# 4996 -24 -220 -195  122   83 -210 -146 -342 -327 -239 -195 -122
# 4997   5 -195 -200   98  102 -200 -146 -337 -327 -229 -195 -137
# 4998  -5 -161 -156   83   73 -161 -117 -298 -293 -190 -166 -107
# 4999   0 -171 -171   88   83 -171 -132 -303 -298 -200 -185 -127
#
# [5000 rows x 12 columns]

# %%
df_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   I       5000 non-null   int64
#  1   II      5000 non-null   int64
#  2   III     5000 non-null   int64
#  3   aVR     5000 non-null   int64
#  4   aVL     5000 non-null   int64
#  5   aVF     5000 non-null   int64
#  6   V1      5000 non-null   int64
#  7   V2      5000 non-null   int64
#  8   V3      5000 non-null   int64
#  9   V4      5000 non-null   int64
#  10  V5      5000 non-null   int64
#  11  V6      5000 non-null   int64
# dtypes: int64(12)
# memory usage: 468.9 KB

# %%
print(f"Shape of ECG DataFrame: {df_raw.shape}")

n_samples, n_channels = df_raw.shape
print(f"Number of channels: {n_channels}")
print(f"Number of samples (time points): {n_samples}")
# Out:
# Shape of ECG DataFrame: (5000, 12)
# Number of channels: 12
# Number of samples (time points): 5000
